# %%
"""
Diagnostic script to understand ScenarioEnv termination behavior.
"""

import os
os.environ["SDL_VIDEODRIVER"] = "dummy"

from metadrive.envs.scenario_env import ScenarioEnv
from metadrive.policy.replay_policy import ReplayEgoCarPolicy

DATA_DIR = "./src/exp_converted"

# Create environment with minimal config (like the tutorial)
env = ScenarioEnv({
    "manual_control": False,
    "reactive_traffic": False,
    "use_render": False,
    "agent_policy": ReplayEgoCarPolicy,
    "data_directory": DATA_DIR,
    "num_scenarios": 10,
})
# Out:
# ERROR:tornado.general:Uncaught exception in ZMQStream callback
# Traceback (most recent call last):
#   File "/mnt/d/Projects/CounterBMT/.venv/lib/python3.9/site-packages/traitlets/traitlets.py", line 632, in get
#     value = obj._trait_values[self.name]
# KeyError: '_control_lock'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/mnt/d/Projects/CounterBMT/.venv/lib/python3.9/site-packages/zmq/eventloop/zmqstream.py", line 565, in _log_error
#     f.result()
#   File "/mnt/d/Projects/CounterBMT/.venv/lib/python3.9/site-packages/ipykernel/kernelbase.py", line 301, in dispatch_control
#     async with self._control_lock:
#   File "/mnt/d/Projects/CounterBMT/.venv/lib/python3.9/site-packages/traitlets/traitlets.py", line 687, in __get__
#     return t.cast(G, self.get(obj, cls))  # the G should encode the Optional
#   File "/mnt/d/Projects/CounterBMT/.venv/lib/python3.9/site-packages/traitlets/traitlets.py", line 649, in get
#     value = self._validate(obj, default)
#   File "/mnt/d/Projects/CounterBMT/.venv/lib/python3.9/site-packages/traitlets/traitlets.py", line 722, in _validate
#     value = self.validate(obj, value)
#   File "/mnt/d/Projects/CounterBMT/.venv/lib/python3.9/site-packages/traitlets/traitlets.py", line 2311, in validate
#     self.error(obj, value)
#   File "/mnt/d/Projects/CounterBMT/.venv/lib/python3.9/site-packages/traitlets/traitlets.py", line 831, in error
#     raise TraitError(e)
# traitlets.traitlets.TraitError: The '_control_lock' trait of an IPythonKernel instance expected a Lock, not the NoneType None.
# [INFO] Environment: ScenarioEnv
# [INFO] MetaDrive version: 0.4.3
# [INFO] Sensors: [lidar: Lidar(), side_detector: SideDetector(), lane_line_detector: LaneLineDetector()]
# [INFO] Render Mode: none
# [INFO] Horizon (Max steps per agent): None

# %%
print(f"\n{'='*60}")
print("ScenarioEnv Diagnostic")
print(f"{'='*60}")

# Reset to scenario 0
obs, info = env.reset(seed=0)

print(f"\nAfter reset:")
print(f"  Info keys: {info.keys()}")

# Run a few steps and check termination
for step in range(20):
    obs, reward, terminated, truncated, info = env.step([1.0, 0])
    
    print(f"\nStep {step}:")
    print(f"  terminated: {terminated}")
    print(f"  truncated: {truncated}")
    print(f"  reward: {reward:.4f}")
    
    # Print relevant info
    for key in ['crash_vehicle', 'crash_object', 'crash_human', 'out_of_road', 'arrive_dest']:
        if key in info:
            print(f"  {key}: {info[key]}")
    
    if terminated or truncated:
        print(f"\n*** TERMINATED at step {step} ***")
        print(f"Full info: {info}")
        break

env.close()
print(f"\n{'='*60}")
# Out:
# [WARNING] No map is provided. Set vehicle to position (0, 0) with heading 0 (base_vehicle.py:340)
# ============================================================
# ScenarioEnv Diagnostic
# ============================================================
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 6
#       3 print(f"{'='*60}")
#       5 # Reset to scenario 0
# ----> 6 obs, info = env.reset(seed=0)
#       8 print(f"\nAfter reset:")
#       9 print(f"  Info keys: {info.keys()}")
#
# File /mnt/d/Projects/CounterBMT/metadrive/metadrive/envs/base_env.py:532, in BaseEnv.reset(self, seed)
#     525 if self.engine is None:
#     526     raise ValueError(
#     527         "Current MetaDrive instance is broken. Please make sure there is only one active MetaDrive "
#     528         "environment exists in one process. You can try to call env.close() and then call "
#     529         "env.reset() to rescue this environment. However, a better and safer solution is to check the "
#     530         "singleton of MetaDrive and restart your program."
#     531     )
# --> 532 reset_info = self.engine.reset()
#     533 self.reset_sensors()
#     534 # render the scene
#
# File /mnt/d/Projects/CounterBMT/metadrive/metadrive/engine/base_engine.py:365, in BaseEngine.reset(self)
#     362 if self.replay_episode and self.only_reset_when_replay and manager is not self.replay_manager:
#     363     # The scene will be generated from replay manager in only reset replay mode
#     364     continue
# --> 365 new_step_infos = manager.reset()
#     366 step_infos = concat_step_infos([step_infos, new_step_infos])
#     368 if _debug_memory_usage:
#
# File /mnt/d/Projects/CounterBMT/metadrive/metadrive/manager/agent_manager.py:103, in VehicleAgentManager.reset(self)
#     101 self._infinite_agents = config["num_agents"] == -1
#     102 self._allow_respawn = config["allow_respawn"]
# --> 103 super(VehicleAgentManager, self).reset()
#
# File /mnt/d/Projects/CounterBMT/metadrive/metadrive/manager/base_manager.py:243, in BaseAgentManager.reset(self)
#     241 config = self.engine.global_config
#     242 self._debug = config["debug"]
# --> 243 self.episode_created_agents = self._create_agents(config_dict=self.engine.global_config["agent_configs"])
#
# File /mnt/d/Projects/CounterBMT/metadrive/metadrive/manager/agent_manager.py:51, in VehicleAgentManager._create_agents(self, config_dict)
#      49     if policy_cls == TrajectoryIDMPolicy or issubclass(policy_cls, TrajectoryIDMPolicy):
#      50         args.append(self.engine.map_manager.current_sdc_route)
# ---> 51     self.add_policy(obj.id, policy_cls, *args)
#      52 return ret
#
# File /mnt/d/Projects/CounterBMT/metadrive/metadrive/manager/base_manager.py:108, in BaseManager.add_policy(self, object_id, policy_class, *policy_args, **policy_kwargs)
#     107 def add_policy(self, object_id, policy_class, *policy_args, **policy_kwargs):
# --> 108     return self.engine.add_policy(object_id, policy_class, *policy_args, **policy_kwargs)
#
# File /mnt/d/Projects/CounterBMT/metadrive/metadrive/engine/base_engine.py:99, in BaseEngine.add_policy(self, object_id, policy_class, *args, **kwargs)
#      98 def add_policy(self, object_id, policy_class, *args, **kwargs):
# ---> 99     policy = policy_class(*args, **kwargs)
#     100     self._object_policies[object_id] = policy
#     101     if self.record_episode:
#
# File /mnt/d/Projects/CounterBMT/metadrive/metadrive/policy/replay_policy.py:21, in ReplayTrafficParticipantPolicy.__init__(self, control_object, track, random_seed)
#      19 self.start_index = 0
#      20 self._velocity_local_frame = False
# ---> 21 self.traj_info = self.get_trajectory_info(track)
#
# File /mnt/d/Projects/CounterBMT/metadrive/metadrive/policy/replay_policy.py:80, in ReplayEgoCarPolicy.get_trajectory_info(self, trajectory)
#      78 def get_trajectory_info(self, trajectory):
#      79     # Directly get trajectory from data manager
# ---> 80     trajectory_data = self.engine.data_manager.current_scenario["tracks"]
#      81     sdc_track_index = str(self.engine.data_manager.current_scenario["metadata"]["sdc_id"])
#      82     ret = []
#
# AttributeError: 'BaseEngine' object has no attribute 'data_manager'
